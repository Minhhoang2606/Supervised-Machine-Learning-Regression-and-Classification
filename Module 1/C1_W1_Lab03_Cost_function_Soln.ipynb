# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate the cost function for various w values
w_values = np.linspace(-1, 2, 100)  # Range of w values
cost_values = [np.mean((w * X - y) ** 2) / 2 for w in w_values]  # Compute J(w)

# Plot the cost function
plt.figure(figsize=(8, 6))
plt.plot(w_values, cost_values, color='blue')
plt.title("U-Shaped Curve of the Cost Function J(w)")
plt.xlabel("w")
plt.ylabel("Cost J(w)")
plt.axvline(1, color='red', linestyle='--', label="Optimal w = 1")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the cost function
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W, B, J_vals, cmap='viridis', alpha=0.8)

# Set axis labels
ax.set_title("3D Surface Plot of Cost Function")
ax.set_xlabel("w (slope)")
ax.set_ylabel("b (intercept)")
ax.set_zlabel("Cost J(w, b)")  # Add this line to label the z-axis

plt.show()

# %%
# Plot the contour map
plt.figure(figsize=(8, 6))
contour = plt.contour(W, B, J_vals, levels=np.logspace(-1, 2, 20), cmap='viridis')
plt.clabel(contour, inline=1, fontsize=8)
plt.title("Contour Plot of Cost Function")
plt.xlabel("w (slope)")
plt.ylabel("b (intercept)")
plt.scatter(1, 0, color='red', label="Optimal Point (w=1, b=0)")
plt.legend()
plt.show()
